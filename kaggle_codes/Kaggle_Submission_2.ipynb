# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split

df = pd.read_csv("train.csv")

#Splitting the data into Train for training the model and test to check the accuracy and effectiveness
X = df.drop(columns=["id", "target"]).values
y = df["target"].values
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15, stratify=y, random_state=42)

#normalization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

#Initial Weight initializer-->'He' 
initializer = tf.keras.initializers.HeNormal()
model = models.Sequential([
    layers.Dense(256, activation="relu", kernel_initializer=initializer, input_shape=(X_train.shape[1],)),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(128, activation="relu", kernel_initializer=initializer),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(64, activation="relu", kernel_initializer=initializer),
    layers.BatchNormalization(),
    layers.Dropout(0.2),

    layers.Dense(1, activation="sigmoid")
])


model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=32,
)

def predict_new(data_row):
    data_row = np.array(data_row).reshape(1, -1)
    data_row = scaler.transform(data_row)
    prob = model.predict(data_row)[0][0]
    label = 1 if prob >= 0.5 else 0
    return label, prob

test_df = pd.read_csv("test.csv")
test_ids = test_df["id"].values
X_test_submit = test_df.drop(columns=["id"]).values
X_test_submit = scaler.transform(X_test_submit)
pred_probs = model.predict(X_test_submit)
pred_labels = (pred_probs >= 0.5).astype(int).flatten()

submission = pd.DataFrame({ "id": test_ids, "target": pred_labels})
submission.to_csv("submission.csv", index=False)
# Out:
# c:\Users\manit\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.5276 - loss: 0.8294 - val_accuracy: 0.4767 - val_loss: 0.9287 - learning_rate: 5.0000e-04
# Epoch 2/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.6482 - loss: 0.6605 - val_accuracy: 0.6933 - val_loss: 0.6438 - learning_rate: 5.0000e-04
# Epoch 3/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7241 - loss: 0.5712 - val_accuracy: 0.8367 - val_loss: 0.4620 - learning_rate: 5.0000e-04
# Epoch 4/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7829 - loss: 0.5007 - val_accuracy: 0.8833 - val_loss: 0.4252 - learning_rate: 5.0000e-04
# Epoch 5/50
# ...
