# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras import layers, models

df = pd.read_csv("train.csv")

X = df.drop(columns=["id", "target"]).values
y = df["target"].values

#Normalization
scaler = StandardScaler()
X = scaler.fit_transform(X)

model = models.Sequential([
    layers.Dense(1024, activation="relu",input_shape=(X.shape[1],)),
    layers.Dropout(0.4),
    layers.Dense(512, activation="relu",),
    layers.Dropout(0.4),
    layers.Dense(256, activation="relu",),
    layers.Dropout(0.3),
    layers.Dense(128, activation="relu",),
    layers.Dropout(0.2),
    layers.Dense(1, activation="sigmoid")
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

history = model.fit(
    X, y,
    epochs=50,
    batch_size=32
)

def predict_new(data_row):
    data_row = np.array(data_row).reshape(1, -1)
    data_row = scaler.transform(data_row)
    prob = model.predict(data_row)[0][0]
    label = 1 if prob >= 0.5 else 0
    return label, prob


test_df = pd.read_csv("test.csv")
test_ids = test_df["id"].values
X_test_submit = test_df.drop(columns=["id"]).values
X_test_submit = scaler.transform(X_test_submit)
pred_probs = model.predict(X_test_submit)
pred_labels = (pred_probs >= 0.5).astype(int).flatten()

submission = pd.DataFrame({"id": test_ids,"target": pred_labels})
submission.to_csv("submission.csv", index=False)
# Out:
# c:\Users\manit\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.8390 - loss: 0.7068
# Epoch 2/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8635 - loss: 0.4855
# Epoch 3/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.8850 - loss: 0.4217
# Epoch 4/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.8900 - loss: 0.3991
# Epoch 5/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.8900 - loss: 0.3767
# Epoch 6/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.8970 - loss: 0.3492
# Epoch 7/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.8955 - loss: 0.3303
# Epoch 8/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8995 - loss: 0.3092
# Epoch 9/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.8990 - loss: 0.3084
# Epoch 10/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.8985 - loss: 0.2743
# Epoch 11/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - accuracy: 0.8990 - loss: 0.2540
# Epoch 12/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.9070 - loss: 0.2499
# Epoch 13/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9225 - loss: 0.2220
# Epoch 14/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9155 - loss: 0.2196
# Epoch 15/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9270 - loss: 0.2058
# Epoch 16/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9345 - loss: 0.1819
# Epoch 17/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.9350 - loss: 0.1603
# Epoch 18/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9420 - loss: 0.1680
# Epoch 19/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9500 - loss: 0.1426
# Epoch 20/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9490 - loss: 0.1441
# Epoch 21/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9605 - loss: 0.1300
# Epoch 22/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9605 - loss: 0.1256
# Epoch 23/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9580 - loss: 0.1230
# Epoch 24/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9710 - loss: 0.0843
# Epoch 25/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.9630 - loss: 0.1013
# Epoch 26/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9740 - loss: 0.0704
# Epoch 27/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9725 - loss: 0.0957
# Epoch 28/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.9700 - loss: 0.0917
# Epoch 29/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9715 - loss: 0.0805
# Epoch 30/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9805 - loss: 0.0530
# Epoch 31/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9800 - loss: 0.0663
# Epoch 32/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9750 - loss: 0.0760
# Epoch 33/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9760 - loss: 0.0684
# Epoch 34/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9795 - loss: 0.0678
# Epoch 35/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9795 - loss: 0.0631
# Epoch 36/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9805 - loss: 0.0625
# Epoch 37/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9810 - loss: 0.0553
# Epoch 38/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9760 - loss: 0.0699
# Epoch 39/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9885 - loss: 0.0396
# Epoch 40/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9805 - loss: 0.0603
# Epoch 41/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9810 - loss: 0.0508
# Epoch 42/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9890 - loss: 0.0399
# Epoch 43/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.9860 - loss: 0.0512
# Epoch 44/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9810 - loss: 0.0658
# Epoch 45/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9845 - loss: 0.0440
# Epoch 46/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.9800 - loss: 0.0654
# Epoch 47/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9820 - loss: 0.0647
# Epoch 48/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9865 - loss: 0.0492
# Epoch 49/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9880 - loss: 0.0385
# Epoch 50/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9935 - loss: 0.0237
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# ✅ submission.csv created successfully!
